# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv("bruteforce.csv")

# %%
df.shape
# Out:
# (14501, 60)

# %%
df.head()
# Out:
#    frame.time_delta  frame.time_delta_displayed  frame.time_epoch  \
# 0          0.000000                    0.000000      1.592812e+09
# 1          0.026297                    0.026297      1.592812e+09
# 2          0.000095                    0.000095      1.592812e+09
# 3          0.000300                    0.000300      1.592812e+09
# 4          0.001360                    0.001360      1.592812e+09
#
#    frame.time_invalid  frame.time_relative            eth.src  \
# 0                 NaN             0.000000  8c:85:90:b3:e6:d9
# 1                 NaN             0.026297  bc:5f:f4:65:87:30
# 2                 NaN             0.026392  8c:85:90:b3:e6:d9
# 3                 NaN             0.026692  8c:85:90:b3:e6:d9
# 4                 NaN             0.028052  bc:5f:f4:65:87:30
#
#              eth.dst        ip.src        ip.dst  tcp.srcport  ...  \
# 0  bc:5f:f4:65:87:30  192.168.1.90  192.168.1.91        55363  ...
# ...

# %%
df.tail()
# Out:
#        frame.time_delta  frame.time_delta_displayed  frame.time_epoch  \
# 14496          0.963651                    0.963651      1.592814e+09
# 14497          0.001615                    0.001615      1.592814e+09
# 14498          0.028347                    0.028347      1.592814e+09
# 14499          0.000284                    0.000284      1.592814e+09
# 14500          0.000056                    0.000056      1.592814e+09
#
#        frame.time_invalid  frame.time_relative            eth.src  \
# 14496                 NaN          2237.391972  8c:85:90:b3:e6:d9
# 14497                 NaN          2237.393587  8c:85:90:b3:e6:d9
# 14498                 NaN          2237.421934  bc:5f:f4:65:87:30
# 14499                 NaN          2237.422218  bc:5f:f4:65:87:30
# 14500                 NaN          2237.422274  8c:85:90:b3:e6:d9
#
#                  eth.dst        ip.src        ip.dst  tcp.srcport  ...  \
# 14496  bc:5f:f4:65:87:30  192.168.1.90  192.168.1.91        61562  ...
# ...

# %%
df.isnull().values.any()  #mengetahui apakah ada data yang kosong atau tidak
# Out:
# True

# %%
def
