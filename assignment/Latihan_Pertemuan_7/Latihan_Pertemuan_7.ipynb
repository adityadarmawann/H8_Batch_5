# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('melb_data.csv')
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 0  3/12/2016       2.5    3067.0       2.0       1.0  1.0     202.0
# 1  4/02/2016       2.5    3067.0       2.0       1.0  0.0     156.0
# 2  4/03/2017       2.5    3067.0       3.0       2.0  0.0     134.0
# 3  4/03/2017       2.5    3067.0       3.0       2.0  1.0      94.0
# 4  4/06/2016       2.5    3067.0       3.0       1.0  2.0     120.0
#
#    BuildingArea  YearBuilt CouncilArea  Lattitude  Longtitude  \
# 0           NaN        NaN       Yarra   -37.7996    144.9984
# 1          79.0     1900.0       Yarra   -37.8079    144.9934
# 2         150.0     1900.0       Yarra   -37.8093    144.9944
# 3           NaN        NaN       Yarra   -37.7969    144.9969
# 4         142.0     2014.0       Yarra   -37.8072    144.9941
#
#               Regionname  Propertycount
# 0  Northern Metropolitan         4019.0
# 1  Northern Metropolitan         4019.0
# 2  Northern Metropolitan         4019.0
# 3  Northern Metropolitan         4019.0
# 4  Northern Metropolitan         4019.0

# %% [markdown]
# # Soal No. 1

# %%
plt.hist(df['Price'])
plt.title('Distribusi Harga Rumah', size = 15)
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
sns.distplot(df['Price'])
plt.title('Distribusi Harga Rumah', size = 15)
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()
# Out:
# /tmp/ipykernel_10608/149103339.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])

# %% [markdown]
# # Soal No. 2

# %%
sns.boxplot(data=df, x='Distance', y='Regionname')
plt.title('Distribusi Jarak ke CBD berdasarkan Nama Region', size=15)
plt.show()

# %% [markdown]
# # Soal No. 3

# %%
sns.barplot(data=df, x='Type', y='Price')
plt.title('Perbandingan Nilai Median Harga Rumah', size=15)
plt.show()

# %% [markdown]
# # Soal No. 4

# %%
sns.scatterplot(data=df, x='Price', y='Distance', hue = 'Type')
plt.title('Korelasi Harga Rumah dan Jarak Rumah ke CBD', size=15)
plt.show()

# %% [markdown]
# # Soal No. 5

# %%
df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG Date  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin  NaT
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin  NaT
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin  NaT
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin  NaT
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson  NaT
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# 0        NaN       Yarra   -37.7996    144.9984  Northern Metropolitan
# 1     1900.0       Yarra   -37.8079    144.9934  Northern Metropolitan
# 2     1900.0       Yarra   -37.8093    144.9944  Northern Metropolitan
# 3        NaN       Yarra   -37.7969    144.9969  Northern Metropolitan
# 4     2014.0       Yarra   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount  Month
# 0         4019.0    NaN
# 1         4019.0    NaN
# 2         4019.0    NaN
# 3         4019.0    NaN
# 4         4019.0    NaN

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.month

# %%
sns.lineplot(data=df, x='Month', y='Price', hue = 'Type')

plt.title('Tren Harga Rumah per Bulan berdasarkan Tipe Rumah', size=15)
plt.xlabel('Month')
plt.ylabel('Price')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'x'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sns.lineplot(data=df, x='Month', y='Price', hue = 'Type')
#       3 plt.title('Tren Harga Rumah per Bulan berdasarkan Tipe Rumah', size=15)
#       4 plt.xlabel('Month')
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:645, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     642 color = kwargs.pop("color", kwargs.pop("c", None))
#     643 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 645 p.plot(ax, kwargs)
#     646 return ax
#
# File ~/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:432, in _LinePlotter.plot(self, ax, kws)
#     427     sort_cols = [var for var in sort_vars if var in self.variables]
#     428     sub_data = sub_data.sort_values(sort_cols)
#     430 if (
#     431     self.estimator is not None
# --> 432     and sub_data[orient].value_counts().max() > 1
#     433 ):
#     434     if "units" in self.variables:
#     435         # TODO eventually relax this constraint
#     436         err = "estimator must be None when specifying units"
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'x'
